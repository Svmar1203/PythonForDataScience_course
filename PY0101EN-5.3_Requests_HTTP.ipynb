# %% [markdown]
# <a href="https://cognitiveclass.ai/?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkPY0101ENSkillsNetwork19487395-2021-01-01">
#     <img src="https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/PY0101EN/Ad/CCLog.png" width="200" align="center">
# </a>

# %% [markdown]
# <h1> HTTP and Requests</h1>
#
# Estimated time needed: **15** minutes
#
# ## Objectives
#
# After completing this lab you will be able to:
#
# *   Understand HTTP
# *   Handle HTTP Requests

# %% [markdown]
# <h2>Table of Contents</h2>
#
# <div class="alert alert-block alert-info" style="margin-top: 20px">
#     <ul>
#         <li>
#             <a href="https://#index">Overview of HTTP </a>
#             <ul>
#                 <li><a href="https://#HTTP">Uniform Resource Locator:URL</a></li>
#                  <li><a href="https://slice/?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkPY0101ENSkillsNetwork19487395-2021-01-01">Request</a></li>
#                 <li><a href="https://stride/?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkPY0101ENSkillsNetwork19487395-2021-01-01">Response</a></li>
#             </ul>
#         </li>
#         <li>
#             <a href="https://#RP">Requests in Python  </a>
#             <ul>
#                 <li><a href="https://#get">Get Request with URL Parameters</a></li>
#                 <li><a href="https://#post">Post Requests </a></li>
#
# </ul>
#
# </div>
#
# <hr>

# %% [markdown]
# <h2 id="">Overview of HTTP </h2>

# %% [markdown]
# When you, the **client**, use a web page your browser sends an **HTTP** request to the **server** where the page is hosted. The server tries to find the desired **resource** by default "<code>index.html</code>". If your request is successful, the server will send the object to the client in an **HTTP response**. This includes information like the type of the **resource**, the length of the **resource**, and other information.
#
# <p>
# The figure below represents the process. The circle on the left represents the client, the circle on the right represents the Web server. The table under the Web server represents a list of resources stored in the web server. In  this case an <code>HTML</code> file, <code>png</code> image, and <code>txt</code> file .
# </p>
# <p>
# The <b>HTTP</b> protocol allows you to send and receive information through the web including webpages, images, and other web resources. In this lab, we will provide an overview of the Requests library for interacting with the <code>HTTP</code> protocol.
# </p

# %% [markdown]
# <div class="alert alert-block alert-info" style="margin-top: 20px">
#          <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-PY0101EN-SkillsNetwork/labs/Module%205/images/reqest_basics.png" width="750" align="center">
#
# </div>

# %% [markdown]
# <h2 id="URL">Uniform Resource Locator: URL</h2>

# %% [markdown]
# Uniform resource locator (URL) is the most popular way to find resources on the web.  We can break the URL into three parts.
#
# <ul>
#     <li><b>scheme</b> this is this protocol, for this lab it will always be <code>http://</code>  </li>
#     <li><b> Internet address or  Base URL </b> this will be used to find the location here are some examples: <code>www.ibm.com</code> and  <code> www.gitlab.com </code> </li>
#     <li><b>route</b> location on the web server for example: <code>/images/IDSNlogo.png</code> </li>
# </ul>

# %% [markdown]
# You may also hear the term Uniform Resource Identifier (URI), URL are actually a subset of URIs. Another popular term is endpoint, this is the URL of an operation provided by a Web server.

# %% [markdown]
# <h2 id="RE">Request </h2>

# %% [markdown]
# The process can be broken into the <b>request</b> and <b>response </b> process.  The request using the get method is partially illustrated below. In the start line we have the <code>GET</code> method, this is an <code>HTTP</code> method. Also the location of the resource  <code>/index.html</code> and the <code>HTTP</code> version. The Request header passes additional information with an <code>HTTP</code> request:

# %% [markdown]
# ![reqest_messege.png](attachment:54503aa8-7b42-4ba8-a080-9a2e4bd73006.png)<div class="alert alert-block alert-info" style="margin-top: 20px">
#          <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-PY0101EN-SkillsNetwork/labs/Module%205/images/reqest_messege.png" width="400" align="center">
# </div>

# %% [markdown]
# When an <code>HTTP</code> request is made, an <code>HTTP</code> method is sent, this tells the server what action to perform.  A list of several <code>HTTP</code> methods is shown below. We will go over more examples later.

# %% [markdown]
# <div class="alert alert-block alert-info" style="margin-top: 20px">
#          <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-PY0101EN-SkillsNetwork/labs/Module%205/images/http_methods.png" width="400" align="center">
# </div>

# %% [markdown]
# <h2 id="RES">Response</h2>

# %% [markdown]
# The figure below represents the response; the response start line contains the version number <code>HTTP/1.0</code>, a status code (200) meaning success, followed by a descriptive phrase (OK). The response header contains useful information. Finally, we have the response body containing the requested file, an <code> HTML </code> document.  It should be noted that some requests have headers.

# %% [markdown]
# <div class="alert alert-block alert-info" style="margin-top: 20px">
#          <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-PY0101EN-SkillsNetwork/labs/Module%205/images/response_message.png" width="400" align="center">
# </div>

# %% [markdown]
# Some status code examples are shown in the table below, the prefix indicates the class. These are shown in yellow, with actual status codes shown in  white. Check out the following <a href="https://developer.mozilla.org/en-US/docs/Web/HTTP/Status?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkPY0101ENSkillsNetwork19487395-2021-01-01">link </a> for more descriptions.

# %% [markdown]
# <div class="alert alert-block alert-info" style="margin-top: 20px">
#          <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-PY0101EN-SkillsNetwork/labs/Module%205/images/status_code.png" width="300" align="center">
# </div>

# %% [markdown]
# <h2 id="RP">Requests in Python</h2>

# %% [markdown]
# Requests is a Python Library that allows you to send <code>HTTP/1.1</code> requests easily. We can import the library as follows:

# %%
import requests

# %% [markdown]
# We will also use the following libraries:

# %%
import os 
from PIL import Image
from IPython.display import IFrame

# %% [markdown]
# You can make a <code>GET</code> request via the method <code>get</code> to [www.ibm.com](http://www.ibm.com/?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkPY0101ENSkillsNetwork19487395-2021-01-01):

# %%
import requests
url='https://www.ibm.com/'
r=requests.get(url)
r
# Out:
# <Response [200]>

# %% [markdown]
# We have the response object <code>r</code>, this has information about the request, like the status of the request. We can view the status code using the attribute <code>status_code</code>.

# %%
import requests
url='https://www.ibm.com/'
r=requests.get(url)
r.status_code
# Out:
# 200

# %% [markdown]
# You can view the request headers:

# %%
print(r.request.headers)
# Out:
# {'User-Agent': 'python-requests/2.26.0', 'Accept-Encoding': 'gzip, deflate, br', 'Accept': '*/*', 'Connection': 'keep-alive', 'Cookie': '_abck=1FF9AB0352430FB2C1DE7E5D7728B52A~-1~~-1~-1~-1; bm_sz=F97B57AA58B5FF0E60612AAA4CD8A612~~3421507~4272952'}

# %% [markdown]
# You can view the request body, in the following line, as there is no body for a get request we get a <code>None</code>:

# %%
print("request body:", r.request.body)
# Out:
# request body: None

# %% [markdown]
# You can view the <code>HTTP</code> response header using the attribute <code>headers</code>. This returns a python dictionary of <code>HTTP</code> response headers.

# %%
header=r.headers
print(r.headers)
# Out:
# {'Cache-Control': 'max-age=301', 'Expires': 'Sat, 01 Jan 2022 17:07:10 GMT', 'Last-Modified': 'Sat, 01 Jan 2022 16:14:11 GMT', 'ETag': '"16819-5d48793fbd7ff"', 'Accept-Ranges': 'bytes', 'Content-Encoding': 'gzip', 'Content-Type': 'text/html', 'X-Akamai-Transformed': '9 18894 0 pmb=mTOE,1', 'Date': 'Mon, 03 Jan 2022 17:50:11 GMT', 'Content-Length': '18963', 'Connection': 'keep-alive', 'Vary': 'Accept-Encoding', 'x-content-type-options': 'nosniff', 'X-XSS-Protection': '1; mode=block', 'Content-Security-Policy': 'upgrade-insecure-requests', 'Strict-Transport-Security': 'max-age=31536000'}

# %% [markdown]
# We can obtain the date the request was sent using the key <code>Date</code>

# %%
header['date']
# Out:
# 'Mon, 03 Jan 2022 17:50:11 GMT'

# %% [markdown]
# <code>Content-Type</code> indicates the type of data:

# %%
header['Content-Type']
# Out:
# 'text/html'

# %% [markdown]
# You can also check the <code>encoding</code>:

# %%
 r.encoding
# Out:
# 'ISO-8859-1'

# %% [markdown]
# As the <code>Content-Type</code> is <code>text/html</code> we can use the attribute <code>text</code> to display the <code>HTML</code> in the body. We can review the first 100 characters:

# %%
r.text[0:100]
# Out:
# '<!DOCTYPE html><html lang="en-US"><head><meta name="viewport" content="width=device-width"/><meta ch'

# %% [markdown]
# You can load other types of data for non-text requests, like images. Consider the URL of the following image:

# %%
# Use single quotation marks for defining string
url='https://gitlab.com/ibm/skills-network/courses/placeholder101/-/raw/master/labs/module%201/images/IDSNlogo.png'

# %% [markdown]
# We can make a get request:

# %%
r=requests.get(url)
r
# Out:
# <Response [200]>

# %% [markdown]
# We can look at the response header:

# %%
print(r.headers)
# Out:
# {'Date': 'Mon, 03 Jan 2022 17:52:51 GMT', 'Content-Type': 'image/png', 'Content-Length': '21590', 'Connection': 'keep-alive', 'Cache-Control': 'max-age=60, public', 'Content-Disposition': 'inline', 'Etag': 'W/"56d66205ba3c6cb8fd1418e601bb3ea8"', 'Permissions-Policy': 'interest-cohort=()', 'Referrer-Policy': 'strict-origin-when-cross-origin', 'X-Content-Type-Options': 'nosniff', 'X-Download-Options': 'noopen', 'X-Frame-Options': 'DENY', 'X-Permitted-Cross-Domain-Policies': 'none', 'X-Request-Id': '01FRGH0GWW49D7A3RRBZQMJ9DK', 'X-Runtime': '0.067534', 'X-Ua-Compatible': 'IE=edge', 'X-Xss-Protection': '1; mode=block', 'GitLab-LB': 'fe-14-lb-gprd', 'GitLab-SV': 'web-gke-us-east1-d', 'CF-Cache-Status': 'REVALIDATED', 'Accept-Ranges': 'bytes', 'Expect-CT': 'max-age=604800, report-uri="https://report-uri.cloudflare.com/cdn-cgi/beacon/expect-ct"', 'Report-To': '{"endpoints":[{"url":"https:\\/\\/a.nel.cloudflare.com\\/report\\/v3?s=BhIvxf36lUYUuGSazkHLUm1L9G0bCyYVMyrNO2sOvSkVIF%2ByVic%2Bj0VqV%2FgaAfub3e9FOorz2KCbxGYIla6QKFanG2M%2BsD7qH5HMabEYMF1V0A7DqNgprMWEzvs%3D"}],"group":"cf-nel","max_age":604800}', 'NEL': '{"success_fraction":0.01,"report_to":"cf-nel","max_age":604800}', 'Vary': 'Accept-Encoding', 'Strict-Transport-Security': 'max-age=31536000', 'Server': 'cloudflare', 'CF-RAY': '6c7e1550afbd57d3-IAD'}

# %% [markdown]
# We can see the <code>'Content-Type'</code>

# %%
r.headers['Content-Type']
# Out:
# 'image/png'

# %% [markdown]
# An image is a response object that contains the image as a <a href="https://docs.python.org/3/glossary.html?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkPY0101ENSkillsNetwork19487395-2021-01-01#term-bytes-like-object">bytes-like object</a>. As a result, we must save it using a file object. First, we specify the file path and
# name

# %%
path=os.path.join(os.getcwd(),'image.png')
path
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_65/3538584580.py in <module>
# ----> 1 path=os.path.join(os.getcwd(),'image.png')
#       2 path
#
# NameError: name 'os' is not defined

# %% [markdown]
# We save the file, in order to access the body of the response we use the attribute <code>content</code> then save it using the <code>open</code> function and write <code>method</code>:

# %%
with open(path,'wb') as f:
    f.write(r.content)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_65/924440188.py in <module>
# ----> 1 with open(path,'wb') as f:
#       2     f.write(r.content)
#
# NameError: name 'path' is not defined

# %% [markdown]
# We can view the image:

# %%
Image.open(path)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_65/3089995092.py in <module>
# ----> 1 Image.open(path)
#
# NameError: name 'Image' is not defined

# %% [markdown]
# <h3>Question 1: write <a href="https://www.gnu.org/software/wget/?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkPY0101ENSkillsNetwork19487395-2021-01-01"><code> wget </code></a></h3>

# %% [markdown]
# In the previous section, we used the <code>wget</code> function to retrieve content from the web server as shown below.  Write the python code to perform the same task. The code should be the same as the one used to download the image, but the file name should be <code>'Example1.txt'</code>.

# %% [markdown]
# <code>!wget -O /resources/data/Example1.txt <https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-PY0101EN-SkillsNetwork/labs/Module%205/data/Example1.txt></code>

# %%
url = https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-PY0101EN-SkillsNetwork/labs/Module%205/data/Example1.txt
path = os.path.join(os.getcwd(),'example1.txt')
r=requests.get(url)
with open(path,'wb') as f:
    f.write(r.content)
# Out:
#   File "/tmp/ipykernel_65/599416862.py", line 1
#     url = https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-PY0101EN-SkillsNetwork/labs/Module%205/data/Example1.txt
#                ^
# SyntaxError: invalid syntax

# %% [markdown]
# <details><summary>Click here for the solution</summary>
#
# ```python
# url='https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-PY0101EN-SkillsNetwork/labs/Module%205/data/Example1.txt'
# path=os.path.join(os.getcwd(),'example1.txt')
# r=requests.get(url)
# with open(path,'wb') as f:
#     f.write(r.content)
#
# ```
#
# </details>

# %% [markdown]
# <h2 id="URL_P">Get Request with URL Parameters </h2>

# %% [markdown]
# You can use the <b>GET</b> method to modify the results of your query, for example retrieving data from an API. We send a <b>GET</b> request to the  server. Like before we have the <b>Base URL</b>, in the <b>Route</b> we append <code>/get</code>, this indicates we would like to preform a <code>GET</code> request. This is demonstrated in the following table:

# %% [markdown]
# ![base_URL_Route.png](attachment:14ed99c7-5249-414a-8351-329d518f2952.png)<div class="alert alert-block alert-info" style="margin-top: 20px">
#          <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-PY0101EN-SkillsNetwork/labs/Module%205/images/base_URL_Route.png" width="400" align="center">
# </div>

# %% [markdown]
# The Base URL is for <code>[http://httpbin.org/](http://httpbin.org/?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkPY0101ENSkillsNetwork19487395-2021-01-01)</code> is a simple HTTP Request & Response Service. The <code>URL</code> in Python is given by:

# %%
url_get='http://httpbin.org/get'

# %% [markdown]
# A <a href="https://en.wikipedia.org/wiki/Query_string?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkPY0101ENSkillsNetwork19487395-2021-01-01">query string</a> is a part of a uniform resource locator (URL), this sends other information to the web server. The start of the query is a <code>?</code>, followed by a series of parameter and value pairs, as shown in the table below. The first parameter name is <code>name</code> and the value is <code>Joseph</code>. The second parameter name is <code>ID</code> and the Value is <code>123</code>. Each pair, parameter, and value is separated by an equals sign, <code>=</code>.
# The series of pairs is separated by the ampersand <code>&</code>.

# %% [markdown]
# <div class="alert alert-block alert-info" style="margin-top: 20px">
#          <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-PY0101EN-SkillsNetwork/labs/Module%205/images/query_string.png" width="500" align="center">
# </div>

# %% [markdown]
# To create a Query string, add a dictionary. The keys are the parameter names and the values are the value of the Query string.

# %%
payload={"name":"Joseph","ID":"123"}

# %% [markdown]
# Then passing the dictionary <code>payload</code> to the <code>params</code> parameter of the <code> get()</code> function:

# %%
r=requests.get(url_get,params=payload)

# %% [markdown]
# We can print out the <code>URL</code> and see the name and values

# %%
r.url
# Out:
# 'https://gitlab.com/ibm/skills-network/courses/placeholder101/-/raw/master/labs/module%201/images/IDSNlogo.png'

# %% [markdown]
# There is no request body

# %%
print("request body:", r.request.body)
# Out:
# request body: None

# %% [markdown]
# We can print out the status code

# %%
print(r.status_code)
# Out:
# 200

# %% [markdown]
# We can view the response as text:

# %%
print(r.text)
# Out:
# �PNG
#
# IHDR ��ZgAMA���asRGB����PLTEDh!bxEi	8f`�5f$Ig2fv7gBiS|Ei��9j�j�m�j�Ggj��A Hh�bFo�Nj���8j�l��7LT�^�4NQ�G˺:�d6η<��7��.�U4K�N�?C�I�l�e6��8�Z4$��'��b���l�0O�>b���JX�G�>$��c��]��X�G�74 ��c���oF'����DIjj�3f��9Y�G�f6D�G'���74�lݧC�Ed�� ��d����p�AtRNSl�@"���2��d�Q�Z�M!)�選8R\zG�h���������xb쮖����Џ����������+c�� IDATx��	c�6���M�D=/��ز��%M��NR�I�4��w:����$%q@\DJ��i�E�����Ӂ���������������������������������������������������������������������F�����Ә�pU ��cIu�7���P��v�)���u\��('S\$�p�X^߿~���¯<}���z
# �T>KEY"�R��,<D���0��[EO�!�!���O�V$�:tx�����߯��\��Ͱ^����SD!���2 ��B&2�~��t�AcwjS5��g\�]�,��Ʃ�|�X�2=���{��OK��\��� ������Q�q�??���ǈ|T����@;w�)���%��b^|���V�7��h�|,T�X3���
# B/�Ʉ�<wؓ󳳳��g��G���7��S��L/q�h�o��8�KL�q� ��������)�����E�ɑ�'_��]@���Ĕ���o%��'w?�899:::?g���N�����)�N�/�&N��6 ��4B,s�3l��xP6��..�OG�O��(�	���N*�Ӑ��XMWFC�HnǒO��6GH~Σ�sdN���|D@9����( 4а]��0_���O�CN�f#ğ<�J>��#XH�����Y:=�ȋ���׀蠡����ۇ�I����F�	2"��ٺ��C
# ��G �)�Iv�K�#�Zos�����Ov���y�1r`#VN@������X��e��U�wy!�ģ��;+��I?$������� H�و�9�،l�N��EL׵�	�m���I{���^l()��qz���{)��3�c���@�*��m �*�շL%�ѝ�vZ��įs�����H �j���F�g!@�;c���w�:kp�׽P�\�@I�TPt�3@�3��y�G�I��/a���oE�8���NHI�T��;@�@x*�hB�%~�����#������� ��s/�'���v�E�KCwwo߾�/G�˔���܋K�#R���q���ٞ���C�-+b#���㭀#�1i& �C��ڗ�O�>%ρ�}O���z��
# ĵ�(hؕ6�9 �'Y	նzP>~����$M�b�=k8�b�n-�8^_:I�4������.�8��0J<�OT��1 =�9a*1uRZ�/��}����!�� �r�v�]+k����s��||�h��bu��dz�ѳ��B"-��#vR�˨޽L�M5���k{;�hhyMm]A&���H�N,IF�]��VX�K9}KL��ŏ?�����n�Ƿ1���w�^�OQ�@��\�`��gtpF��5�C����L>����h@:�[�E�B�V�K��|6���1B!�FB���܋�^3
# �F�)"{�;�4�Kd��y:��n���x����E�JEXDk�L��B���]��~0l& _T5l& �`�uLG3k�T�e����?~~}����$��s�/�^Q~�_�&B�_�>y�Q�$�;�<�]xz�4�R���|���o�qH��! �B'X�lhy
# ?l1Q*¢3,m@�}�H�$�x�D@�mD7��-O��������t��ߓ.dp0�|�6AB+ekk��R�v�_	ɽm|W	 y��]R6 vOC���(a���3�u�\�Y��ۻq���n@�/m�Տ$�ы���EX�9�ǌ4!͵�~�h- _ZH�b�Wl7������w�m� ���c=����%�$G�� ������މ�o������Ϣ�yI�<Vy� �퀘�V���^�)�5�R1��o�MJ��@Z)�GQ�Hey���wE�n�T��-s�@�2l Z�)S"� \�G���9^��ᙍG�g�R�"7�8Έi�]�6b�H���IBH���,<��^�Jz�iR-��!������G���Gg*�Ί�G
# ���9��Y�QP���m�f��~@��H�G)���������>�?�"_��ي�2#��32��{����dHw����z���b����ï
# �A��ǫ�޼Z�J�C����|�x9��g�z���Ii����7����맭���r˺���3� ę��ub��P=�׀P�x����������?~z�沬��8 �<q'�H��b�A�eb�ݥN�H#�|��`c+JȬ��X<��m�Co�.!+��> �N�Hc:��+e=�ϯ>����KsWS,7H��,���+1�I��_-F�l��L8�=���LʼM�`��R�$�4^�`����|�*�d��.){�@�9��|C�j#����R�0�E ���^h��V�c�ŊJ��=�
# ���^]���C	�|?K��)�Kb(� -uj ?�󯈏˳���K�ʈ��Z��t	&Y6�_@޼�G��\�H	|� $M�H)�y�+��x-� �
# �e]�\}(#q�#)�ݽ ���!��1��䀼zc6��z6�:� 7 �~2�쫃���S�Zy��$�d9d?y#�߲!�"�W�_����'�B��5� �:@��X
# I�`�C� X�$�41���+�u�1M�백�h¦��8R)>� �t���{IT�d2�m��
# @fՀ����
# :mb�':��S)��w��4�o��V���۟>;W��Y�$%L�H����o<!%R�$��4�&��1������w���ǋ�^R�$��E���
# s�y���� ~�	u��3ap�{���jW�L@����;@�Գ�^}�^a�N�|F����?�������C�r_�l@��� ͬ�z_K-VI�|�ʬ�$Խ^2�����q�w�[/O�����	Q�,:� �\�[����$*�Iyytvvv����)��S�LB)ܮ��~�N@���6�:2M�`#!�b3&Y��;
# �(d��Z�F����D���
# F�'Y��gJ�0�*�7�z~�z*������V��Ii����|ŧY�tw�~۸��a#��bB��M&��|:�hJ5�b@� (:�*�|�_W3i�l#5����wG�]B��b>%������N0(u�?�q����j9m�V|�!�*���f�)̨G"��B�����۷߄���?_#��1H�4�nݞ^�߼*��p{[NQ$�JN�cM���Vk=�
# �J�|uy9<�t�E�'�U
# �b
# @Z�
# ��'��f���:*��Y,a����%���f�a{��L�@��4�	e|&FxG�s~�x+���h#���B�&��1F8|��!���F�*m
# !G�����o���(���!H8߾�E��)[�]^}��E>|��Ju'��Fβ��f�������ws�6@ܼ%�3@~�|E�yT�ȇ��X��ط@^������wH��� ��e�d�B�K^ <c��S#�r�z����2�Ftj#VW���H�q^R:��E��)H�)���[��������S��h=�ZR<~�2��i�~`O���H*y���x�z���2��������\
# @L����Ayt#dS�hn4v\����A��^r�N�@.�+$��N���=�A� 4F���oR ��BS�+o>@��A� 5�m!j�\�{vP5;���l�Yz �
# ��؛�n@|p��9K� ��D�_
# �;Dk�d������)����r�(@�Õ��vR5;�z}Ļ �MS���@���{J��%E)�_NI�񫌽�y�:,�|���bmA5�B�Hña�~������Ͽ���Z�^���V�DuivB���O���S	���ӑϏ�$m!�_e�ț�:+�Z�D;
# >�,k�锸/�z�BM6���@��KN���C �|"������\��* �gk���X/�׿�d�d�G^<�������<ӑ�r;+�r��,,���25��o�QD��z��(�*�i{�	�o^(�o�ly=�S,�|z,�����41�Nt��h��Gv����o�C۟f� ���5�\6���A����f�9��7,�6�}���o�z����<6�R)wO�(ԪŊ�m�g[�7��lg��~l��Æ�
# HbA����jM�|@�"g�v<�˗/߅��z�q�=�o���@n�S?H�b����ϟ=%x���G2����& �=��l���)�StN^��Q���]�֣�
# ����*���]*\]r�uv����J�L6��x��b����+܉;�"���k!~:�cI�0]�S��u�i�:���Lus��`�ͲA�̵
#  ~z�.�7�H$����<_�_rV��ե����+�
# �����+4���'��{[�[�k'
# G� eB��g^�N�=ռJ��	Mm�k�f�  ciZ!s��Y�ٳLF�=[]]���AHSb����S�� y���D���t�IA@�c)��S�W��$�~g�@3���Q��>�9��	@�/{E/�3)�	 J�o��Ͱ
# ի��߿z�~ifj|U�9R&�JA�W M@��p	|<|:^1>(!�Fr"��)X�+D%�=��SF��:@��&J�;;Kl��Dm�#�H�u��= R�ï����@d�S�BH��H�+8P�EҰDk�5+e!�R@la���Z�@Z� ��W�(��?�1�y��޼O�>���n*7���0��߮�JD�� ?+��\ M$h_}�u_�uw��SdϰE��BH
# X(i	 ����A����~��6bnr9S}����*�@NO-�B�"Y
# Ҋd��<cqx|���x���a'Xm7V
# B8�I{��9�z�>���Iӱ\^���Zѳ.�7�W�\��� �.X�	@Z�p��v��pu�Ĥ�!���O�-�sJ;la^�~�������-%�B��=��u�"����?2�Yooj|R;lA���-��b��S�=I��^�jfҖd;��%��P�������*v��dJ2�+��\��F��:)i��Ёt��ӧ'O��d�tw�I��'9���Ûmw�gn�q!@>M�v�L#WnV�x�j5H�!�ŧ��˔��e�&� f�đ4�)=�:+~���?�ǳ�r�d���̳��ob$B�^�:�"@�34���<�˓Ŝ�d�/
# ��r���!����H�y����ɦ�L&��z��?����<37=/��nn����v������@$�򸗔 o�믫| IDATv�����[Dh0�t��������nJ�!�����*7 ���=��/E�M�,�@��(G!�=%^�.��S,My�f��駋'�Ht$��>����4y�EA�>8������ ~0�8�B���di�z��q�}}�B�s,v�.��1�VKk���3�1�N�#�fX�V�c��xSI��,V���Y[�W^y�XP�;�)NRx�����B� ,��Iu�E_��\P�;V$G��	B&%�� m_(��:�����u9X��l
# �X��x���t@��v�/��v� �Z�4 �*aӖ����mPt�<����ɓ'����t:&5�j���R���A���x���SoG��W��0���[�I��l��m��|�q^C��������]�An�������N�9��$�6]T؎�iT����ݎ��/
# ��������3�MD�������� [B�S
# ;
# ���(�!I'�|���/eB�l���MbOI|s���r6����� l@�[��Wp���s.���S�=���h��� �e��/���?��%/|J��c����~2�����{�]�j=_��R�Wj�����r�C<Hh!��g��ry'����j���&�6`�}�Z�+�$맟~`�	��"��V; ��2����D�B(!�T��_�m�-�e����iU@>7��||���,�����4v��o��zW`�d����ϊ�P&�����&/l�����K�p��t��!�� �澉�+�<�) l۔: ~�3�������YO�ֈD��C63&�P=����ZZn��)��K��[�7/AsQ�5TC��V�5@����↩�ho;ύ��0���cQ�C9TW8lV	�������c�^�/j���� K@�߸j��r�l6 ��*�)�9�6�#l�E�fX��Q����6kg����,@���5ٌ�h#aû��� ɻ����*g���z���u��q��e��g=@^��9�i�8F�����rȰ"�U:l�B�#{�B��tO�M@�Y+Fg�����V�����mP��Z�ݩT��"�I̭6�*����2��ы�h��J�ᛴ޾�[L�z���VQB^<z�S[�L^<�t������1��E�/�����8? ܹU��"�}N7�����)�#�
# ���
# B�ݷ���`�ϭ��:�\�6e�=��.YyY�L
# {�ͱ����'�Id��Rnd@� �^��do6�-�vR���ؙ��M�����2Nv�`��Ʈtn!3��*�ҝ= �Aj�<�������n�w#
# ��w��c�t\�sv�* I�sZ^�� D���gL<c����� vr�����L����]/�O�b�3��#I�xMT��h�iA�V@���y��V}�H�{��4
# �Uݬq��= ���%��Qu7��Um�2Ӯł��A��o��7��� F:$WMc�����g�v]�4I�,�˙O��i,@���AT�808��&1HD�ǟ�[6:���(��t��@� �A-��(�ǍK�X�u�( � S�������?:�U��&�g�bk|�B��	 U��po�M���e7���'j=���7u�� �Ar���~{�x=Y��({(r3����jK��"��T�-�	��N���������f�� ]���r�>��z�
# �~5���X��3�˨,*o6۬��Jc����	%4� Dy?�<�w�=�\^]�V�b���y�Z]]&��d���f)+=@r1@�����YLs=��5���@pE�����d�&$oV�k:@��A:�{�e���5#W33�+�4ֺ[��u��9��t
# �Av��k6�(�� �y��Z�l��[m�r.>Ҙ`����Z��&�����^��l�	��Wfvk�GO�b����q=�{&�H�@N���!���z���=���妱6�y�ʅ��zV�����@�"B����B�?�Y]��4V$6O����Z�l�ѱ�����0R�O�I���25�j^�����X��<E E��E�G��F��ï�`'*h�@v�YC�'��AlL�S
# ��	9BӼ����ȑ������wJ��Q#��X{ԙ'ge���䨡�D�8,:,(S	��3�5��؜�6c�A����l6+�&J�@r2�h: �I	��R����i����K~l����������r�|�������y��]�H���;H'' ����kal^��s@v� �z�7�]�\����߫������z�:: 	@�mL��\�|�8g��f@�^`����;�D�R" ��A��r���
# �u�8@��1��F�Wsi�\7
# H��4���4V�b� �];�r�;)���������\y�s@�MH��P <@�+����|�eBR& ���Uٓ�r��z�kɱ
# @J���$�Ӵaz}�:(�}}=���WO��Ri����,B����t��e�׻�Nǻ�9rX�T@'L7/Wy����xPa��������*X��<��Gj�i
#  yBtR. ,
# 9@�)n^���g�3�xR;ɳ$G�@J�p;��2u�*�e�6�7b� ���	 �b��V�_./g��6Q��&G �d@�~�8����~�3��i��0B8�\ς�:��)��I��/�?{EK��@.��]r@'BM�g�*�^-Gg�d��о��0�l �=�}� erP���F��,zL2�)�����d׀�C³p�B���B=�=l@�0$n�����R	 ����A'כq�m��>� 2:=;9�@$��eӮ��g�:�$��8��6;���% ����
# ����x�\��������PqwY=��uv1ݓ�c��T�D.��$��� ,��H���P9�X$���ŖBb:���q�O�T
# 5�c�ȁ��s���99�8շR9 a�Nm�1�Hb�ޚ�2�8)��@��������a�zkĤ�qv\�=�Z�J	l�"B��9�!I4�[ϖB����E�j#��Ӏ�CJ�����ֲc�8'G�������׊
# ���2Ŝ䠌���N��Y���x�����z����3�� $����x�����Iu�qL�c4*��: L]1 ���+4��:�\ooy}}�����z����eZ����q�������2���:"9��S���ӧ�	�~}�,����QǨ��jt@���9�Z�N}D�}�������i=}}?-�;�8;U�	I1�C�������.����������zZ!4��q\�ulnaB@����P���k����{�ךr�# ��3;��lN�D���{H��'�9�s~�rB¥�=�k-�|P)��.��J���.`���
# ]�l���y����������G��v�nzs��2� �y=�|��Z{�HfX��z�3+����;����A�m�<������#{S�+�z��<�
# �Q]��h�K������;���D8�76"�aQzN@����"+�eB�}sb ��w�=?�jt���{��<@|�8��<2�?8$@$k���U��uol�4@H`�ިF���*���p�7߰
# jV��6R�<oI{��M�5�ur��"N���������.��������a;{���U���ნ����[�@$y��Ea��������AYKk�lU{m���-�W��
# F��J�m�v��U�<M������Xe�Z.���X��O���X�QU����x�:a�?S��fܔ����/K���KI�'eƊ�
# ��pph�|�{����Z
# %��'�Ļ^� A�1*ې�U8�ɼ$�&�����D!
# EZj"A�1��u���/���j?�2Z��S�xa>r�����]����F�1:�5�zV��O@�5��r�,ə�jcsz;ȷn���fe�-�J�	�`��[�]��|$_^���,�O���� �6�{�cO	���g���&�����[ë[wZ�4����(X����T�7/�\`�ܷ��z�(r��c��	!����H�R[��#�!{�퐰�n�uW:jln���%����Ɔ�ݱt������q�u�QW�=��j�Ǟ��9�'~jK'�u|v��M���+vG��ڣ�N~w?�2���G3�Z	&4i1~�1ʿ�&��9��H�D��|A+���)
# d�$~HRJV9_rNKvo�Ӭ����k�ً%�L� �G#�@����H$*	��Ҝ��(�8��!�R�(�J[��-������D@�_�4��&��������N�Ytz%����[i��9�TU���4R���g$~[ۑd���Pݤ_Wp�Y�u���}�H@�ٕW��G�p���_���6Hf�>�\�JJ&į�:�:2��:�9�>N/�0��x#�R�m����K3ZIp�Qy*(��������}��aR�q�i�U�,&�`���U�o2 ��n�
# !��
# "F�8��4K�ԧ�Ѓ8���9���6��\@6٭��߽#�#���f�'��cTV�Z��kX̑��H@�a��I	�Y�Dj��\ah�1/!��o�_l�slo�^�{Md}{aI>��s9��%�#���ݣ8��;�ok@�I���^�;0��*�8!��D�\!���� qUB�*�:Z�	{v!���EZݠ�#)���θ.R犈h�c4*�׶���
# [H��%�b����EN��/(.	W��wԶϩ�B�f��u���3[�]�G����H�Znd�9���S�;X��A�>�^C;�8-$�o��+�@B�-#iB�Oj�S��U�{��;���=��m_Z�#~^����\��Uu�=:�G��&�h�gI?�Na�D �*3h��������$X^O'��%�L��F�݃8~7��y���7�F��#��^JJ��-�S��P�F8.rzVi�h����v{Z4��q�n�U	�/�����7�e;g&�����uYC_}��"h��Sn`y�����H��Yl�`��Qj��J?�A�)m��&h�f�m���㸮k�y�Y�i�6�]ڌ\��I����xeVU{Փ�W�{�<��?6���
# 0�4>�=��\_�͈a�|F�j�6���5����YE�����f��z
# U0j<6��	LtL9�����jm5�F˺�X��2�S)�$��\TR���Z��FE܃Ev��,}� 6��c�y�L|
# ���L{�fm3k��N���wu�؈���_��{ZŒa��O1��ͣ��զ�r?bkw�!0����h��Pb(,!)qk�,�lO���E�qH�zwT�[a��j#��Q�56��$�#�����K`.^�&�Z��}��Z��Q�"�UyH�?
# e�ؚGe�G|�L�-�Yf�!^��P`���~l�<��B.rZM�B��N�ʍ<_�l�"8�(H2ٰ��.�\r7:+�6bu��f��=c����m������nI�u�+�M|�h���㽂��kO)���}9۝���!κ9èH
# *v��^p��VV�+�i�Tw	�qF�`��㓰�E�M�������Y��Bv�����{t3w����:a�L�41L�0:an�5�*��b�����,v�}��=�ΰ/:q�eƠ{9�U`]�t�c�h�
# �0=\@�Ȝk0�_���'�N�Y*TBx���ZF�R��)7�J�$a%~+���bb��a�V��e%��kl7?�[<³�T���N�gg�4����`3|rP��hۯ�+�*R�K���0hGApP�ذU63<ɜ��〚�$�j�L�Wݮ� j
# !N��AAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAP�do��AI=l��A��>��
# ��Cݮa;�6��x2����y-�R�A ��5��fw�3F֘�3bd���u�(@��vƨdȠ$@���j ���J�����oJȆ��P. ��<5
# �y\|܁�����'z���q���5@C�:'��y����C1 �5�R����	H�q}�Oqj{��}_CK>�]k��N7�N�;�@JDh![)�X��� �� �����,�߶�j��Y�p�;��cZ���bc��v�VceW��qD,��H����9�7�.oʣ��#D��ּ�q����z7ͽ`��Պ�R�l���g>Vf�IDAT��R�'�r�����T��A������/�r
# G�9T*�r�a��F�%} ��I�}s�Zoc�?C��Z�Āl~�H��آ��#d([l�Ͱ�<E/@�����ǱT�m���-@AeG����T@:�b��7��X6g�%�_qǝ/c#�#zG�W2HN̲b��.Q��Q�ۍݓ��h��d�Z�/8Y��uG�l%Y��J�^��8��~��X�;����.�%$� Q���ҍ]�Mٻ�R�s�Gl�̿����K�X�V���
# W3���ǣ�t� ۜ�ё�z+~��d��`u�k��9��~h��k��}c�aD����)�ܟ�
# @���ȓ���@���MOr�܃������w��~�p5���q��Um����cIO�Q��}N|@�?���V& �|!]#9<�Y%���~=�������be<f7�k��ۡZ v�ö$kN��H?J�7�R�be2?����/pq~a(Y�1�A�� ��-�L��}gs廝��J���9V_>��Ȋ��s,> ��q�G<_�%�k.�vv��"y��l@"�2��髍&��)�aٲr�>o���]�Ǳ�����~[	�( &)��g�mQ�x>] �&�͛?�2�$���0����c��O��W�y�:H�d�nח����X��edJ�M�w) ����aY���1����c��M��" 6���PhCQ���3��N�F׼R�96o���X&�h�)���: �����>CJCR ��J����V	U
# �A�B@,��#~��\N܉��C7w�k-�X��� ���Ɍ������t���)����k<wɧ�{Q�A�^(� ����qx�Ǝ�g�X��x3,�Jz@�]I M�
# q��^}�����r������H�ռCi5�@v���-),H�9�����om0��c�-���M��m��+y�(�p.��eR }��q�$�G4��a�t�eE���W�W���J��eW"#/�=tصH5�x�����
# �O=�C����R#��'�����k���/7�3tS����M�� ��;d�(vq��DRs��rLO���y�x�8�}"���)� �%J?$��v7'���:����w?O�,��猸*��j7	�T�����rW��a~����¸�D�xb�Yʔ%���b �u�P�9H��dP+ ���3�x��=��g���_�Y���w�YSY�J��{w��9�)y3}~��0{��M�*��� �+�����>/[�H�R ���+@��sc�:���{q��#����
# !�{�H������������#JH 	B�؊�����r�|��"�#BH& qB��ڎ�����20�H�|u=A����Z�,��?���5;�G�A���I�vb5�o�K�c��V�&O+̺U��<�����w#W��L��n�vJ}d��y-t������8~@�%�kŞa�J=#�?��cA� A� @�@� A�@� A���`�AAAAAAAAAAAAAAAAAAAAAAAAAA-���Ȉ�@�{����ߐ?NJ���h�����&#�������P�G�?��6�U\���|?"S���3>�<E�e�[����=�7䏓����n�� W_�[���ڢ����J?��q����^�`�x�?p�W8���p
# �D	9P@2��zt5������b@�|�	Q$Bȁb�}b�D�=���j1 ݬg�*�����&ԏ}b�+��R��}sO6"�`7���o�c����qRr؏nF+��]�=�}����3�oZ�gq�oQ����{�&,�r߻Ϳʢ5�����)����r������M��=6yw�2S�}�Z�.�������B>��)�\@��_n+s�3�������+����JG�t{�FX1�$f!;D�ŧ�g݀�1����r@��D���/R̀�3��HUKq����bdV|IC^ ��=X����q�/�]���#@����`K��9 yՕ%�rR�������;�d�������2���(=��
# N�^ ��6 *|��~�c!��������u|���G{q8�" ��)��y��N^�լ���C5>��6�-{WD��)�d���דw�j�0��D�������������k�@��$�����# �N��O^P^�^ � ֐�#c�qY�����������5bH��) iY�����G�d�e@"k"�
# ��n;��swԩ�I��A�M��.�p:u+r�!vv�r���s7e��I�^#6wHl��ܚ�s���&-d�$��~�L���	���ղ$́��)Vi��^o�Bv�&J���3�$/F/#{2���<��y��R!��kħ�$~���Jc�.
# ��<dB�\@���;D�=�K*�,d�8�<��I�:�,��y��o���vR����U��
# ��{��&r@����	H�!����u1��.c��س�@�K�G��@T�?��G��w��}4c��p;����W���ud�� �e\���,ko�#�a'�l~������U����j�$:�:��@���D-d'�l�PF�Zo�Ώ�k$L\Y�^�>XR�{�����E@���s9��N2"D#���Kj}M��^�����iC��D�޽ڷ��iQ�6$�%��̞F0 ���+ ۝S����0���k�����Ս��=$�<r�t�˲�|ͥ�Ί�!��$��{
# ��{(��*@8d�&�B�c�ـ���"�D��@�XR!���p@��C!@�v"#���َ����@��(�˖;�7�*��/��rt}у����ջ�]�G��x����)�$wq+$��k �R�+�������)��Ⱥ�`��x��������ݏ��#���L��Sȟ[O����B�~�gwÐN��8����$rF��B��0F���D�x��!�
# �~+buHI�D�V�Qx�qZ���@J"$:��H�{(�v��>!V�he{���c+���r���E�#r�+G��1�=�����7\�W�^Xv�_�+z07�Y����D�(����ڢ����������������������������������������������������������������������������5}�05]d�IEND�B`�

# %% [markdown]
# We can look at the <code>'Content-Type'</code>.

# %%
r.headers['Content-Type']
# Out:
# 'image/png'

# %% [markdown]
# As the content <code>'Content-Type'</code> is in the <code>JSON</code> format we can use the method <code>json()</code>, it returns a Python <code>dict</code>:

# %%
r.json()
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# /tmp/ipykernel_65/661903446.py in <module>
# ----> 1 r.json()
#
# ~/conda/envs/python/lib/python3.7/site-packages/requests/models.py in json(self, **kwargs)
#     908                     # used.
#     909                     pass
# --> 910         return complexjson.loads(self.text, **kwargs)
#     911
#     912     @property
#
# ~/conda/envs/python/lib/python3.7/json/__init__.py in loads(s, encoding, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     346             parse_int is None and parse_float is None and
#     347             parse_constant is None and object_pairs_hook is None and not kw):
# --> 348         return _default_decoder.decode(s)
#     349     if cls is None:
#     350         cls = JSONDecoder
#
# ~/conda/envs/python/lib/python3.7/json/decoder.py in decode(self, s, _w)
#     335
#     336         """
# --> 337         obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     338         end = _w(s, end).end()
#     339         if end != len(s):
#
# ~/conda/envs/python/lib/python3.7/json/decoder.py in raw_decode(self, s, idx)
#     353             obj, end = self.scan_once(s, idx)
#     354         except StopIteration as err:
# --> 355             raise JSONDecodeError("Expecting value", s, err.value) from None
#     356         return obj, end
#
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)

# %% [markdown]
# The key <code>args</code> has the name and values:

# %%
r.json()['args']
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# /tmp/ipykernel_65/2458426581.py in <module>
# ----> 1 r.json()['args']
#
# ~/conda/envs/python/lib/python3.7/site-packages/requests/models.py in json(self, **kwargs)
#     908                     # used.
#     909                     pass
# --> 910         return complexjson.loads(self.text, **kwargs)
#     911
#     912     @property
#
# ~/conda/envs/python/lib/python3.7/json/__init__.py in loads(s, encoding, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     346             parse_int is None and parse_float is None and
#     347             parse_constant is None and object_pairs_hook is None and not kw):
# --> 348         return _default_decoder.decode(s)
#     349     if cls is None:
#     350         cls = JSONDecoder
#
# ~/conda/envs/python/lib/python3.7/json/decoder.py in decode(self, s, _w)
#     335
#     336         """
# --> 337         obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     338         end = _w(s, end).end()
#     339         if end != len(s):
#
# ~/conda/envs/python/lib/python3.7/json/decoder.py in raw_decode(self, s, idx)
#     353             obj, end = self.scan_once(s, idx)
#     354         except StopIteration as err:
# --> 355             raise JSONDecodeError("Expecting value", s, err.value) from None
#     356         return obj, end
#
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)

# %% [markdown]
# <h2 id="POST">Post Requests  </h2>

# %% [markdown]
# Like a <code>GET</code> request, a <code>POST</code> is used to send data to a server, but the <code>POST</code> request sends the data in a request body. In order to send the Post Request in Python, in the <code>URL</code> we change the route to <code>POST</code>:

# %%
url_post='http://httpbin.org/post'

# %% [markdown]
# This endpoint will expect data as a file or as a form. A form is convenient way to configure an HTTP request to send data to a server.

# %% [markdown]
# To make a <code>POST</code> request we use the <code>post()</code> function, the variable <code>payload</code> is passed to the parameter <code> data </code>:

# %%
r_post=requests.post(url_post,data=payload)

# %% [markdown]
# Comparing the URL from the response object of the <code>GET</code> and <code>POST</code> request we see the <code>POST</code> request has no name or value pairs.

# %%
print("POST request URL:",r_post.url )
print("GET request URL:",r.url)

# %% [markdown]
# We can compare the <code>POST</code> and <code>GET</code> request body, we see only the <code>POST</code> request has a body:

# %%
print("POST request body:",r_post.request.body)
print("GET request body:",r.request.body)

# %% [markdown]
# We can view the form as well:

# %%
r_post.json()['form']

# %% [markdown]
# There is a lot more you can do. Check out <a href="https://requests.readthedocs.io/en/master/?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkPY0101ENSkillsNetwork19487395-2021-01-01">Requests </a> for more.

# %% [markdown]
# <hr>

# %% [markdown]
# ## Authors
#
# <p><a href="https://www.linkedin.com/in/joseph-s-50398b136/?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkPY0101ENSkillsNetwork19487395-2021-01-01" target="_blank">Joseph Santarcangelo</a> <br>A Data Scientist at IBM, and holds a PhD in Electrical Engineering. His research focused on using Machine Learning, Signal Processing, and Computer Vision to determine how videos impact human cognition. Joseph has been working for IBM since he completed his PhD.</p>

# %% [markdown]
# ### Other Contributors
#
# <a href="https://www.linkedin.com/in/jiahui-mavis-zhou-a4537814a?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkPY0101ENSkillsNetwork19487395-2021-01-01">Mavis Zhou</a>

# %% [markdown]
# ## Change Log
#
# | Date (YYYY-MM-DD) | Version | Changed By | Change Description           |
# | ----------------- | ------- | ---------- | ---------------------------- |
# | 2021-12-20        | 2.1     | Malika     | Updated the links            |
# | 2020-09-02        | 2.0     | Simran     | Template updates to the file |
# |                   |         |            |                              |
# |                   |         |            |                              |
#
# ## <h3 align="center"> © IBM Corporation 2020. All rights reserved. <h3/>
